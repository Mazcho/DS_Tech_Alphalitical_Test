# %% [markdown]
# # DS - Tech Test Alphalitical

# %% [markdown]
# # 1. Load DataSet

# %%
# library baca dataset
import pandas as pd

# # url dataaset dari github
# url_data_train = 'https://raw.githubusercontent.com/IndoNLP/indonlu/master/dataset/smsa_doc-sentiment-prosa/train_preprocess.tsv'
# url_data_testing = 'https://raw.githubusercontent.com/IndoNLP/indonlu/master/dataset/smsa_doc-sentiment-prosa/test_preprocess.tsv'
# url_data_valid = 'https://raw.githubusercontent.com/IndoNLP/indonlu/master/dataset/smsa_doc-sentiment-prosa/valid_preprocess.tsv'

#memberikan nama kolom ( karena pada dataset tidak memiliki nama kolom)
nama_kolom = ["text","label"]

#load dataset dari link Github
data_train = pd.read_csv('train_preprocess.tsv', sep="\t", header=None, names=nama_kolom)
data_testing = pd.read_csv('test_preprocess.tsv', sep="\t", header=None, names=nama_kolom)
data_valid = pd.read_csv('valid_preprocess.tsv', sep="\t", header=None, names=nama_kolom)

# %%
#menampilkan data train
data_train
# Out:
#                                                     text     label
# 0      warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1      mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2      lokasi strategis di jalan sumatera bandung . t...  positive
# 3      betapa bahagia nya diri ini saat unboxing pake...  positive
# 4      duh . jadi mahasiswa jangan sombong dong . kas...  negative
# ...                                                  ...       ...
# 10995                                       tidak kecewa  positive
# 10996  enak rasa masakan nya apalagi kepiting yang me...  positive
# 10997        hormati partai-partai yang telah berkoalisi   neutral
# 10998  pagi pagi di tol pasteur sudah macet parah , b...  negative
# 10999  meskipun sering belanja ke yogya di riau junct...  positive
#
# [11000 rows x 2 columns]

# %%
#menampilkan data testing
data_testing
# Out:
#                                                   text     label
# 0    kemarin gue datang ke tempat makan baru yang a...  negative
# 1    kayak nya sih gue tidak akan mau balik lagi ke...  negative
# 2    kalau dipikir-pikir , sebenarnya tidak ada yan...  negative
# 3    ini pertama kalinya gua ke bank buat ngurusin ...  negative
# 4    waktu sampai dengan gue pernah disuruh ibu lat...  negative
# ..                                                 ...       ...
# 495  kata nya tidur yang baik itu minimal enam jam ...   neutral
# 496                  indonesia itu ada di benua asia .   neutral
# 497  salah satu kegemaran anak remaja indonesia sek...   neutral
# 498  melihat warna hijau bisa bikin mata jadi lebih...  positive
# 499  bondan winarno yang suka bilang maknyus sekara...   neutral
#
# [500 rows x 2 columns]

# %%
#menampilkan data validasi
data_valid
# Out:
#                                                    text     label
# 0     meski masa kampanye sudah selesai , bukan bera...   neutral
# 1                                            tidak enak  negative
# 2     restoran ini menawarkan makanan sunda . kami m...  positive
# 3     lokasi di alun alun masakan padang ini cukup t...  positive
# 4     betapa bejad kader gerindra yang anggota dprd ...  negative
# ...                                                 ...       ...
# 1255  film tncfu , tidak cocok untuk penonton yang t...  negative
# 1256  indihome ini mahal loh bayar nya . hanya , pen...  negative
# 1257  be de gea , cowok cupu yang takut dengan pacar...  negative
# 1258  valen yang sangat tidak berkualitas . konentat...  negative
# 1259  restoran ini menjadi tempat pilihan saya berbu...  positive
#
# [1260 rows x 2 columns]

# %% [markdown]
# # 2. Data Cleansing dan Preprocessing

# %% [markdown]
# ## 2.1 Pengecekan Missing Value

# %%
#mengecek nilai missing value pada dataset pelatihan
if data_train.isna().sum().sum() == 0:
    print("Tidak ada nilai missing value")
    print(data_train.isna().sum())
else:
    print("Ada missing value : ")
    print(data_train.isna().sum())
# Out:
# Tidak ada nilai missing value
# text     0
# label    0
# dtype: int64

# %%
#mengecek nilai missing value pada dataset pelatihan
if data_valid.isna().sum().sum() == 0:
    print("Tidak ada nilai missing value")
    print(data_valid.isna().sum())
else:
    print("Ada missing value : ")
    print(data_valid.isna().sum())
# Out:
# Tidak ada nilai missing value
# text     0
# label    0
# dtype: int64

# %% [markdown]
# ## 2.2 Pembersihan Teks

# %%
#import regular expression untuk melakukan pembersihan data
import re

# %%
#membuat fungsi untuk pembersihan teks yang dapat digunakan untuk inputan user dan pemebrsihan data training
def pembersih_text(text):
    #membuat semua teks jadi huruf kecil
    text = text.lower()
    
    #menghapus special karaketer dari teks
    text_bersih = re.sub(r'[^\w\s]', '', text)
    
    #mengpus spasi ekstra
    text_bersih = " ".join(text_bersih.split())
    
    #pengembalian nilai kedalam variabel teks_bersih
    return text_bersih

# %%
#melakukan pemebersihan pada dataset training kolom teks
data_train["text"] = data_train["text"].apply(pembersih_text)

# %%
#melakukan pemebersihan pada dataset training kolom teks
data_valid["text"] = data_valid["text"].apply(pembersih_text)

# %% [markdown]
# ## 2.3 Menghapus StopWord Bahasa Indoensia menggunakan NLTK (Natural Language ToolKit)

# %% [markdown]
# Melakukan setting dulu untuk load stopword bahasa indonesia

# %%
# #panggil librari NTLK dahulu
# import nltk
# from nltk.corpus import stopwords

# #unduh stopwordnya
# nltk.download('stopwords')

# #menyeting stopword untuk bahasa indonesia
# stop_word = set(stopwords.words('indonesian'))

# %%
# #Membuat fungsi penghapusan stopword bahasa indonesia
# def hapus_stopword(text):
#     #melakukan pemecahan teks menggunakan split
#     kata = text.split()
    
#     #membuat filter kata-kata yang bukan stopwords
#     kata_tanpa_stopword = [kata for kata in kata if kata.lower() not in stop_word]
    
#     # Menggabungkan kata-kata tanpa stopwords menjadi sebuah string kembali
#     teks_tanpa_stopword = ' '.join(kata_tanpa_stopword)
    
#     return teks_tanpa_stopword

# %%
# #melakukan pemebersihan stop_word
# data_train["text"] = data_train["text"].apply(hapus_stopword)

# %%
# data_train

# %%
# #melakukan pemebersihan stop_word
# data_valid["text"] = data_valid["text"].apply(hapus_stopword)

# %%
# data_valid

# %% [markdown]
# ## 2.4 Melakukan Stemming pada data bahasa indonesia menggunakan library Sastrawi

# %% [markdown]
# Melakukan setting dulu untuk stemming bahasa indonesia pakai sastrawi

# %%
# #import library
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# # Inisialisasi objek stemmer
# factory = StemmerFactory()
# stemmer = factory.create_stemmer()

# def steming_text(text):
#     return stemmer.stem(text)

# %%
# #melakukan steming teks indonesia
# data_train["text"] = data_train["text"].apply(steming_text)

# %%
# data_train

# %%
# #melakukan steming teks indonesia
# data_valid["text"] = data_valid["text"].apply(steming_text)

# %%
# data_valid

# %%
from tensorflow.keras.layers import Input, Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Misalkan df_training adalah DataFrame untuk dataset pelatihan dan df_validasi adalah DataFrame untuk dataset validasi

# Mengambil teks dan label dari DataFrame training dan validasi
train_texts = data_train['text'].tolist()
train_labels = data_train['label'].tolist()
valid_texts = data_valid['text'].tolist()
valid_labels = data_valid['label'].tolist()

# Tokenisasi teks
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_texts)

# Mengonversi teks ke dalam urutan token
train_sequences = tokenizer.texts_to_sequences(train_texts)
valid_sequences = tokenizer.texts_to_sequences(valid_texts)

# Padding urutan token
maxlen = 100  # Misalkan panjang maksimum token
train_padded = pad_sequences(train_sequences, maxlen=maxlen, padding='post')
valid_padded = pad_sequences(valid_sequences, maxlen=maxlen, padding='post')

# Mengonversi label pelatihan dan validasi menjadi format numerik
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
valid_labels_encoded = label_encoder.transform(valid_labels)

# Membangun model CNN
V = len(tokenizer.word_index)  # Jumlah kata dalam kosakata
D = 20  # Dimensi embedding
T = maxlen  # Panjang maksimum urutan token

# Definisi input layer
i = Input(shape=(T,))

# Definisi layer embedding
x = Embedding(input_dim=V+1, output_dim=D)(i)

# Convolutional layer pertama
x = Conv1D(32, 3, activation='relu')(x)
x = MaxPooling1D(3)(x)

# Convolutional layer kedua
x = Conv1D(64, 3, activation='relu')(x)
x = MaxPooling1D(3)(x)

# Convolutional layer ketiga
x = Conv1D(128, 3, activation='relu')(x)

# Global Max Pooling layer
x = GlobalMaxPooling1D()(x)

# Dense layer dengan softmax activation
x = Dense(5, activation='softmax')(x)  # Misalkan output memiliki 5 kelas

# Membangun model
model = Model(inputs=i, outputs=x)

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Melatih model
history = model.fit(train_padded, train_labels_encoded, epochs=20, validation_data=(valid_padded, valid_labels_encoded))

# Evaluasi model
valid_predictions_probs = model.predict(valid_padded)
valid_predictions = valid_predictions_probs.argmax(axis=-1)

# Menghasilkan matriks kebingungan
conf_matrix = confusion_matrix(valid_labels_encoded, valid_predictions)

# Visualisasi matriks kebingungan
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Tampilkan laporan klasifikasi
class_report = classification_report(valid_labels_encoded, valid_predictions, target_names=label_encoder.classes_)
print("Classification Report:")
print(class_report)

# Visualisasi akurasi dan loss
import matplotlib.pyplot as plt

# Visualisasi akurasi
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Visualisasi loss
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.6337 - accuracy: 0.7334 - val_loss: 0.4728 - val_accuracy: 0.7857
# Epoch 2/20
# 344/344 [==============================] - 2s 5ms/step - loss: 0.3300 - accuracy: 0.8709 - val_loss: 0.3708 - val_accuracy: 0.8667
# Epoch 3/20
# 344/344 [==============================] - 2s 5ms/step - loss: 0.1628 - accuracy: 0.9427 - val_loss: 0.3723 - val_accuracy: 0.8778
# Epoch 4/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0715 - accuracy: 0.9728 - val_loss: 0.4818 - val_accuracy: 0.8730
# Epoch 5/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0360 - accuracy: 0.9855 - val_loss: 0.5607 - val_accuracy: 0.8698
# Epoch 6/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0226 - accuracy: 0.9894 - val_loss: 0.6410 - val_accuracy: 0.8706
# Epoch 7/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9903 - val_loss: 0.7769 - val_accuracy: 0.8579
# Epoch 8/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0146 - accuracy: 0.9911 - val_loss: 0.7655 - val_accuracy: 0.8611
# Epoch 9/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0134 - accuracy: 0.9915 - val_loss: 0.8546 - val_accuracy: 0.8603
# Epoch 10/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9936 - val_loss: 1.0633 - val_accuracy: 0.8524
# Epoch 11/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9915 - val_loss: 0.8811 - val_accuracy: 0.8579
# Epoch 12/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9929 - val_loss: 0.9358 - val_accuracy: 0.8627
# Epoch 13/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0315 - accuracy: 0.9885 - val_loss: 0.9033 - val_accuracy: 0.8611
# Epoch 14/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0232 - accuracy: 0.9935 - val_loss: 0.9151 - val_accuracy: 0.8635
# Epoch 15/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0056 - accuracy: 0.9989 - val_loss: 0.9153 - val_accuracy: 0.8746
# Epoch 16/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.9998 - val_accuracy: 0.8714
# Epoch 17/20
# 344/344 [==============================] - 2s 6ms/step - loss: 9.0928e-04 - accuracy: 0.9999 - val_loss: 1.0612 - val_accuracy: 0.8667
# Epoch 18/20
# 344/344 [==============================] - 2s 6ms/step - loss: 9.3346e-04 - accuracy: 0.9998 - val_loss: 1.0392 - val_accuracy: 0.8579
# Epoch 19/20
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 1.0521 - val_accuracy: 0.8683
# Epoch 20/20
# 344/344 [==============================] - 2s 6ms/step - loss: 7.6335e-04 - accuracy: 0.9998 - val_loss: 1.0736 - val_accuracy: 0.8667
# 40/40 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.88      0.84       394
#      neutral       0.73      0.71      0.72       131
#     positive       0.93      0.89      0.91       735
#
#     accuracy                           0.87      1260
#    macro avg       0.82      0.83      0.82      1260
# weighted avg       0.87      0.87      0.87      1260

# %%
def preprocess_text(text):
    # Tokenisasi teks
    sequence = tokenizer.texts_to_sequences([text])
    # Padding urutan token
    padded_sequence = pad_sequences(sequence, maxlen=maxlen, padding='post')
    return padded_sequence

def classify_text(text):
    # Prediksi kelas
    text_sequence = preprocess_text(text)
    prediction_prob = model.predict(text_sequence)[0]
    predicted_class_index = prediction_prob.argmax()
    predicted_class = label_encoder.classes_[predicted_class_index]
    return predicted_class

# Pengujian model dengan input pengguna
user_input = input("Masukkan teks untuk diklasifikasikan: ")
predicted_class = classify_text(user_input)
print("Hasil klasifikasi:", predicted_class)
# Out:
# Masukkan teks untuk diklasifikasikan: kita akan semakin cerdas jika kita terus menerus melatih otak kita
# 1/1 [==============================] - 0s 19ms/step
# Hasil klasifikasi: positive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Mengambil teks dan label dari DataFrame training dan validasi
train_texts = data_train['text'].tolist()
train_labels = data_train['label'].tolist()
valid_texts = data_valid['text'].tolist()
valid_labels = data_valid['label'].tolist()

# Tokenisasi teks
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_texts)

# Mengonversi teks ke dalam urutan token
train_sequences = tokenizer.texts_to_sequences(train_texts)
valid_sequences = tokenizer.texts_to_sequences(valid_texts)

# Padding urutan token
maxlen = 50  # Misalkan panjang maksimum token
train_padded = pad_sequences(train_sequences, maxlen=maxlen, padding='post')
valid_padded = pad_sequences(valid_sequences, maxlen=maxlen, padding='post')

# Mengonversi label pelatihan dan validasi menjadi format numerik
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
valid_labels_encoded = label_encoder.transform(valid_labels)

# One-hot encoding untuk label
train_labels_encoded = tf.keras.utils.to_categorical(train_labels_encoded, num_classes=len(label_encoder.classes_))
valid_labels_encoded = tf.keras.utils.to_categorical(valid_labels_encoded, num_classes=len(label_encoder.classes_))

# Mengatur seed untuk reproduktibilitas
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# Mendefinisikan arsitektur model
def get_model(vocab_size, embed_dim, maxlen):
    model = Sequential()
    model.add(Embedding(vocab_size, embed_dim, input_length=maxlen))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    return model

# Menentukan parameter model
vocab_size = len(tokenizer.word_index) + 1
embed_dim = 64

# Membuat model
model = get_model(vocab_size, embed_dim, maxlen)

# Melatih model
history = model.fit(train_padded, train_labels_encoded, epochs=10, validation_data=(valid_padded, valid_labels_encoded))

# Evaluasi model
valid_predictions_probs = model.predict(valid_padded)
valid_predictions = valid_predictions_probs.argmax(axis=-1)

# Menghasilkan matriks kebingungan
conf_matrix = confusion_matrix(valid_labels_encoded.argmax(axis=-1), valid_predictions)

# Visualisasi matriks kebingungan
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Tampilkan laporan klasifikasi
class_report = classification_report(valid_labels_encoded.argmax(axis=-1), valid_predictions, target_names=label_encoder.classes_)
print("Classification Report:")
print(class_report)

# Visualisasi akurasi dan loss
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# Fungsi untuk mengklasifikasikan input teks pengguna
def preprocess_user_input(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = " ".join(text.split())
    return text

def classify_text(model, tokenizer, label_encoder, text):
    seq = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(seq, maxlen=maxlen, padding='post')
    pred = model.predict(padded).argmax(axis=-1)
    return label_encoder.inverse_transform(pred)[0]

user_input = input("Masukkan teks untuk diklasifikasikan: ")
user_input_preprocessed = preprocess_user_input(user_input)
predicted_class = classify_text(model, tokenizer, label_encoder, user_input_preprocessed)
print("Hasil klasifikasi:", predicted_class)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 50, 64)            1149760
#
#  conv1d_8 (Conv1D)           (None, 48, 128)           24704
#
#  global_max_pooling1d_2 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,174,851
# Trainable params: 1,174,851
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 344/344 [==============================] - 4s 9ms/step - loss: 0.6240 - accuracy: 0.7340 - val_loss: 0.4302 - val_accuracy: 0.8492
# Epoch 2/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.3303 - accuracy: 0.8820 - val_loss: 0.3249 - val_accuracy: 0.8817
# Epoch 3/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.1925 - accuracy: 0.9348 - val_loss: 0.3212 - val_accuracy: 0.8778
# Epoch 4/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.1252 - accuracy: 0.9586 - val_loss: 0.3488 - val_accuracy: 0.8770
# Epoch 5/10
# 344/344 [==============================] - 3s 9ms/step - loss: 0.0790 - accuracy: 0.9740 - val_loss: 0.3815 - val_accuracy: 0.8770
# Epoch 6/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.0486 - accuracy: 0.9855 - val_loss: 0.4337 - val_accuracy: 0.8778
# Epoch 7/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.0384 - accuracy: 0.9888 - val_loss: 0.5044 - val_accuracy: 0.8714
# Epoch 8/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.0289 - accuracy: 0.9915 - val_loss: 0.5252 - val_accuracy: 0.8714
# Epoch 9/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 0.5673 - val_accuracy: 0.8738
# Epoch 10/10
# 344/344 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9962 - val_loss: 0.5936 - val_accuracy: 0.8714
# 40/40 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.82      0.83       394
#      neutral       0.78      0.74      0.76       131
#     positive       0.90      0.92      0.91       735
#
#     accuracy                           0.87      1260
#    macro avg       0.84      0.83      0.83      1260
# weighted avg       0.87      0.87      0.87      1260
# Masukkan teks untuk diklasifikasikan: kita akan semakin cerdas jika kita terus menerus melatih otak kita
# 1/1 [==============================] - 0s 17ms/step
# Hasil klasifikasi: positive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Mengambil teks dan label dari DataFrame training dan validasi
train_texts = data_train['text'].tolist()
train_labels = data_train['label'].tolist()
valid_texts = data_valid['text'].tolist()
valid_labels = data_valid['label'].tolist()

# Tokenisasi teks
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_texts)

# Mengonversi teks ke dalam urutan token
train_sequences = tokenizer.texts_to_sequences(train_texts)
valid_sequences = tokenizer.texts_to_sequences(valid_texts)

# Padding urutan token
maxlen = 100  # Misalkan panjang maksimum token
train_padded = pad_sequences(train_sequences, maxlen=maxlen, padding='post')
valid_padded = pad_sequences(valid_sequences, maxlen=maxlen, padding='post')

# Mengonversi label pelatihan dan validasi menjadi format numerik
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
valid_labels_encoded = label_encoder.transform(valid_labels)

# One-hot encoding untuk label
train_labels_encoded = tf.keras.utils.to_categorical(train_labels_encoded, num_classes=len(label_encoder.classes_))
valid_labels_encoded = tf.keras.utils.to_categorical(valid_labels_encoded, num_classes=len(label_encoder.classes_))

# Mengatur seed untuk reproduktibilitas
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# Mendefinisikan arsitektur model
def get_model(max_features, embed_dim):
    model = Sequential()
    model.add(Embedding(max_features, embed_dim, input_length=maxlen))
    model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=2))    
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(len(label_encoder.classes_), activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    return model

# Menentukan parameter model
max_features = len(tokenizer.word_index) + 1
embed_dim = 100

# Membuat model
model = get_model(max_features, embed_dim)

# Melatih model
history = model.fit(train_padded, train_labels_encoded, epochs=10, validation_data=(valid_padded, valid_labels_encoded))

# Evaluasi model
valid_predictions_probs = model.predict(valid_padded)
valid_predictions = valid_predictions_probs.argmax(axis=-1)

# Menghasilkan matriks kebingungan
conf_matrix = confusion_matrix(valid_labels_encoded.argmax(axis=-1), valid_predictions)

# Visualisasi matriks kebingungan
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Tampilkan laporan klasifikasi
class_report = classification_report(valid_labels_encoded.argmax(axis=-1), valid_predictions, target_names=label_encoder.classes_)
print("Classification Report:")
print(class_report)

# Visualisasi akurasi dan loss
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# Fungsi untuk mengklasifikasikan input teks pengguna
def preprocess_user_input(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = " ".join(text.split())
    return text

def classify_text(model, tokenizer, label_encoder, text):
    seq = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(seq, maxlen=maxlen, padding='post')
    pred = model.predict(padded).argmax(axis=-1)
    return label_encoder.inverse_transform(pred)[0]

user_input = input("Masukkan teks untuk diklasifikasikan: ")
user_input_preprocessed = preprocess_user_input(user_input)
predicted_class = classify_text(model, tokenizer, label_encoder, user_input_preprocessed)
print("Hasil klasifikasi:", predicted_class)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 100)          1796500
#
#  conv1d_6 (Conv1D)           (None, 100, 32)           9632
#
#  max_pooling1d_4 (MaxPooling  (None, 50, 32)           0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 50, 32)            3104
#
#  max_pooling1d_5 (MaxPooling  (None, 25, 32)           0
#  1D)
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dense_2 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 1,862,739
# Trainable params: 1,862,739
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 344/344 [==============================] - 19s 50ms/step - loss: 0.6022 - accuracy: 0.7528 - val_loss: 0.4862 - val_accuracy: 0.8008
# Epoch 2/10
# 344/344 [==============================] - 17s 50ms/step - loss: 0.3813 - accuracy: 0.8433 - val_loss: 0.3890 - val_accuracy: 0.8532
# Epoch 3/10
# 344/344 [==============================] - 17s 50ms/step - loss: 0.1862 - accuracy: 0.9401 - val_loss: 0.3630 - val_accuracy: 0.8794
# Epoch 4/10
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0886 - accuracy: 0.9748 - val_loss: 0.4579 - val_accuracy: 0.8786
# Epoch 5/10
# 344/344 [==============================] - 18s 53ms/step - loss: 0.0535 - accuracy: 0.9865 - val_loss: 0.4412 - val_accuracy: 0.8913
# Epoch 6/10
# 344/344 [==============================] - 18s 53ms/step - loss: 0.0410 - accuracy: 0.9893 - val_loss: 0.6022 - val_accuracy: 0.8659
# Epoch 7/10
# 344/344 [==============================] - 18s 53ms/step - loss: 0.0337 - accuracy: 0.9918 - val_loss: 0.5847 - val_accuracy: 0.8794
# Epoch 8/10
# 344/344 [==============================] - 18s 53ms/step - loss: 0.0276 - accuracy: 0.9936 - val_loss: 0.5184 - val_accuracy: 0.8817
# Epoch 9/10
# 344/344 [==============================] - 18s 53ms/step - loss: 0.0196 - accuracy: 0.9958 - val_loss: 0.5821 - val_accuracy: 0.8849
# Epoch 10/10
# 344/344 [==============================] - 18s 52ms/step - loss: 0.0194 - accuracy: 0.9954 - val_loss: 0.6636 - val_accuracy: 0.8881
# 40/40 [==============================] - 1s 8ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.86      0.86       394
#      neutral       0.78      0.68      0.73       131
#     positive       0.92      0.94      0.93       735
#
#     accuracy                           0.89      1260
#    macro avg       0.85      0.83      0.84      1260
# weighted avg       0.89      0.89      0.89      1260
# Masukkan teks untuk diklasifikasikan: kita akan semakin cerdas jika kita terus menerus melatih otak kita
# 1/1 [==============================] - 0s 20ms/step
# Hasil klasifikasi: positive

# %%
data_testing
# Out:
#                                                   text     label
# 0    kemarin gue datang ke tempat makan baru yang a...  negative
# 1    kayak nya sih gue tidak akan mau balik lagi ke...  negative
# 2    kalau dipikir-pikir , sebenarnya tidak ada yan...  negative
# 3    ini pertama kalinya gua ke bank buat ngurusin ...  negative
# 4    waktu sampai dengan gue pernah disuruh ibu lat...  negative
# ..                                                 ...       ...
# 495  kata nya tidur yang baik itu minimal enam jam ...   neutral
# 496                  indonesia itu ada di benua asia .   neutral
# 497  salah satu kegemaran anak remaja indonesia sek...   neutral
# 498  melihat warna hijau bisa bikin mata jadi lebih...  positive
# 499  bondan winarno yang suka bilang maknyus sekara...   neutral
#
# [500 rows x 2 columns]
